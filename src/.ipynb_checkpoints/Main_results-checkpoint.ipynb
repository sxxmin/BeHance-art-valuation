# %%
from collections import Counter
from glob import glob
import joblib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pds
from sklearn.metrics import r2_score, mean_absolute_error
from scipy.stats import pearsonr, spearmanr
from tqdm import tqdm

# %% [markdown]
# ### Figure 1. Predictive performance of artwork-only, artist-only, and combined specifications for appreciation and view counts

# %%
# get r score each cases
paths = sorted(glob('../dataset/models/260812/*.values'))

infos = []
for _path in tqdm(paths):
    tokens = _path.split('/')[-1].split('.')[0].split('+')
    _values = joblib.load(_path)
    
    # p values IS ALMOST ZEROS
    infos.append(
        tokens+[
            r2_score(_values['y'], _values['y_hat']), 
            pearsonr(_values['y'], _values['y_hat'])[0], 
            spearmanr(_values['y'], _values['y_hat'])[0],
            mean_absolute_error(_values['y'], _values['y_hat'])
        ]
    )

results_df = pds.DataFrame(infos, columns='Model,Target,Variables,w/ control variable,$r$,pearson r,spearman r,MAE(log-scale)'.split(','))
del results_df['w/ control variable']
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 214.00it/s]

# %%
results_df
# Out:
#    Model        Target Variables       $r$  pearson r  spearman r  \
# 0    EBM  appreciation       All  0.370949   0.616747    0.623135
# 1    EBM  appreciation    Artist  0.229628   0.493049    0.492935
# 2    EBM  appreciation   Artwork  0.231649   0.496408    0.514570
# 3    EBM          view       All  0.412818   0.651708    0.658525
# 4    EBM          view    Artist  0.250846   0.516457    0.517505
# 5    EBM          view   Artwork  0.240646   0.544488    0.543682
# 6     LR  appreciation       All  0.203242   0.480935    0.499993
# 7     LR  appreciation    Artist  0.057603   0.338879    0.355335
# 8     LR  appreciation   Artwork  0.169120   0.414875    0.441163
# 9     LR          view       All  0.264898   0.535797    0.548589
# 10    LR          view    Artist  0.092587   0.373987    0.391553
# 11    LR          view   Artwork  0.183528   0.471247    0.478855
# 12    NB  appreciation       All -0.139072   0.462420    0.506424
# ...

# %% [markdown]
# ### Figure 2. Model-specific top-20 feature-importance rankings for XGB and EBM fitted with both predictor groups

# %%
# Design of feature importance
xgb_model_paths= sorted(glob('../dataset/models/260812/XGB*All+False.models'))
xgb_varsn_paths= sorted(glob('../dataset/models/260812/XGB*All+False.column'))
ebm_model_paths= sorted(glob('../dataset/models/260812/EBM*All+False.models'))
ebm_varsn_paths= sorted(glob('../dataset/models/260812/EBM*All+False.column'))

# %%
# XGB
for _xgb_model_path, _xgb_varsn_path in zip(xgb_model_paths, xgb_varsn_paths):
    print(_xgb_varsn_path)
    xgb_new_df = pds.DataFrame()
    
    fname = _xgb_model_path.split('/')[-1].split('.')[0]
    model_name = fname.split('+')[0]; target_name = fname.split('+')[1]
    _model_info, _vars_info = joblib.load(_xgb_model_path), joblib.load(_xgb_varsn_path)
    
    xgb_new_df['Variables'] = _vars_info
    xgb_new_df['Importance'] = _model_info.feature_importances_
    pds.set_option('display.max_colwidth', None)
    print(xgb_new_df.sort_values('Importance', ascending=False).reset_index(drop=True).iloc[:20])
# Out:
# ../dataset/models/260812/XGB+appreciation+All+False.column
#                                                 Variables  Importance
# 0                 Artist_Inter_project_publication_period    0.056140
# 1                      Artwork_Creative_fields-(Branding)    0.025436
# 2              Artist_Curation_status_of_the_last_project    0.023703
# 3                  Artwork_Creative_fields-(Architecture)    0.019125
# 4                               Artwork_Contributor_count    0.014720
# 5                       Artwork_Creative_fields-(Fashion)    0.013158
# 6                        Artist_Residency-(Taiwan Region)    0.012217
# 7                              Artwork_Image_sample_count    0.011954
# 8                               Artist_Collaborator_count    0.010792
# 9                 Artist_Residency-(United Arab Emirates)    0.010251
# 10                     Artwork_Creative_fields-(Painting)    0.009730
# 11              Artist_Platform_membership_join_year_2013    0.008859
# ...

# %%
# EBM
for _ebm_model_path, _ebm_varsn_path in zip(ebm_model_paths, ebm_varsn_paths):
    print(_ebm_varsn_path)
    fname = _ebm_model_path.split('/')[-1].split('.')[0]
    model_name = fname.split('+')[0]; target_name = fname.split('+')[1]
    
    _model_info, _vars_info = joblib.load(_ebm_model_path), joblib.load(_ebm_varsn_path)
    idx2vars = {i:v for i,v in enumerate(_vars_info)}
    
    alloc_names = []
    for _pair in _model_info.term_features_:
        if len(_pair)==1:
            alloc_names.append([idx2vars[_pair[0]], None])
        elif len(_pair)==2:
            alloc_names.append([idx2vars[_pair[0]], idx2vars[_pair[1]]])

    ebm_new_df = pds.DataFrame(alloc_names, columns='Variable 1,Variable 2'.split(','))
    ebm_new_df['Importance'] = _model_info.term_importances()
    
    single_ebm_df = ebm_new_df.loc[
        pds.isna(ebm_new_df['Variable 2'])
    ].copy().sort_values('Variable 1').reset_index(drop=True); del single_ebm_df['Variable 2']
    pair_ebm_df = ebm_new_df.loc[
        ~pds.isna(ebm_new_df['Variable 2'])
    ].copy().sort_values('Variable 1').reset_index(drop=True)
    
    pds.set_option('display.max_colwidth', None)
    print(single_ebm_df.sort_values('Importance', ascending=False).reset_index(drop=True).iloc[:20])
        
    group_ids = []
    for a_row in pair_ebm_df.iterrows():
        _var1, _var2 = a_row[1]['Variable 1'], a_row[1]['Variable 2']

        if (_var1.split('_')[0]=='Artist') and (_var2.split('_')[0]=='Artist'):
            group_ids.append('Artist & Artist')
        elif (_var1.split('_')[0]=='Artist') and (_var2.split('_')[0]=='Artwork'):
            group_ids.append('Artist & Artwork')
        elif (_var1.split('_')[0]=='Artwork') and (_var2.split('_')[0]=='Artwork'):
            group_ids.append('Artwork & Artwork')
        elif (_var1.split('_')[0]=='Artwork') and (_var2.split('_')[0]=='Artist'):
            group_ids.append('Artist & Artwork')
        else:
            group_ids.append(None)
    pair_ebm_df['Group'] = group_ids
    pair_ebm_df.to_csv(f'../dataset/group_tables/{fname}.csv', index=False)
# Out:
# ../dataset/models/260812/EBM+appreciation+All+False.column
#                                                      Variable 1  Importance
# 0                       Artist_Inter_project_publication_period    0.109768
# 1                                    Artwork_Image_sample_count    0.054174
# 2                            Artwork_Visual_Features_Complexity    0.042431
# 3   Artist_Visual_simillarity_latent_PCA_embeddings_Neighboring    0.041669
# 4                                     Artwork_Contributor_count    0.040169
# 5                                        Artist_Career_timeline    0.037688
# 6                    Artist_Curation_status_of_the_last_project    0.035623
# 7                         Artwork_Assigned_creative_field_count    0.031400
# 8                Artwork_Visual_Features_red_Standard_deviation    0.025337
# 9                        Artwork_Creative_fields-(Illustration)    0.024507
# 10                                    Artist_Collaborator_count    0.024249
# ...

# %% [markdown]
# ### Figure 3. Composition and illustrative examples of pairwise feature interactions selected by EBM for appreciation and view-count prediction

# %%
appr_df = pds.read_csv("../dataset/group_tables/EBM+appreciation+All+False.csv")
view_df = pds.read_csv("../dataset/group_tables/EBM+view+All+False.csv")

# %%
appr_group_counter = dict(Counter(appr_df.Group))
view_group_counter = dict(Counter(view_df.Group))

g2index = {'Artist': 1,'Artwork': 0}

# %%
target2sum_val = dict()
target2sum_val['appreciation'] = np.zeros((2,2))
target2sum_val['view'] = np.zeros((2,2))

for _group in appr_df.Group.unique():
    try:
        g1, g2 = _group.split(' & ')
        target2sum_val['appreciation'][g2index[g2]][g2index[g1]] = appr_df.query(
            "Group == @_group"
        ).Importance.sum()
    except:
        pass
    
for _group in appr_df.Group.unique():
    try:
        g1, g2 = _group.split(' & ')
        target2sum_val['view'][g2index[g2]][g2index[g1]] = view_df.query(
            "Group == @_group"
        ).Importance.sum()
    except:
        pass

# %%
Counter(appr_df.Group)
# Out:
# Counter({'Artist & Artwork': 237,
#          'Artist & Artist': 104,
#          'Artwork & Artwork': 60})

# %%
Counter(view_df.Group)
# Out:
# Counter({'Artist & Artist': 114,
#          'Artist & Artwork': 228,
#          'Artwork & Artwork': 59})

# %%
base_df = pds.read_csv('../dataset/baseline_counts_k401.csv')

_label = 'appreciation'

a_df = pds.read_csv(f'../dataset/group_tables/EBM+{_label}+All+False.csv')
a_df = a_df.sort_values('Importance', ascending=False).reset_index(drop=True)

cat2cnt = dict()
cat2cnt['Artwork & Artwork'] = [0]*a_df.shape[0]
cat2cnt['Artist & Artwork'] = [0]*a_df.shape[0]
cat2cnt['Artist & Artist'] = [0]*a_df.shape[0]

for _idx, _row in a_df.iterrows():
    try:
        cat2cnt[_row.Group][_idx] = 1
    except:
        pass
    
fig, ax = plt.subplots(1,2,figsize=(12, 4))

ax[0].set_title('Appreciation')
ax[0].set_xlabel('# of rank at 90%(default)')
ax[0].set_ylabel('Count')

l1, = ax[0].plot(np.array(cat2cnt['Artwork & Artwork']).cumsum(), label='Artwork & Artwork')
l2, = ax[0].plot(np.array(cat2cnt['Artist & Artwork']).cumsum(), label='Artist & Artwork')
l3, = ax[0].plot(np.array(cat2cnt['Artist & Artist']).cumsum(), label='Artist & Artist')

ax[0].plot(np.array(base_df['Artwork&Artwork']), linestyle='--', color=l1.get_color())
ax[0].plot(np.array(base_df['Artist&Artwork']), linestyle='--', color=l2.get_color())
ax[0].plot(np.array(base_df['Artist&Artist']), linestyle='--', color=l3.get_color())

ax[0].legend()

tmp_df = pds.DataFrame()
tmp_df['# of rank'] = [i for i in range(1, tmp_df.shape[0]+1)]

_label = 'view'

a_df = pds.read_csv(f'../dataset/group_tables/EBM+{_label}+All+False.csv')
a_df = a_df.sort_values('Importance', ascending=False).reset_index(drop=True)

cat2cnt = dict()
cat2cnt['Artwork & Artwork'] = [0]*a_df.shape[0]
cat2cnt['Artist & Artwork'] = [0]*a_df.shape[0]
cat2cnt['Artist & Artist'] = [0]*a_df.shape[0]

for _idx, _row in a_df.iterrows():
    try:
        cat2cnt[_row.Group][_idx] = 1
    except:
        pass
    

ax[1].set_title('View')
ax[1].set_xlabel('# of rank at 90%(default)')
ax[1].set_ylabel('Count')

l1, = ax[1].plot(np.array(cat2cnt['Artwork & Artwork']).cumsum(), label='Artwork & Artwork')
l2, = ax[1].plot(np.array(cat2cnt['Artist & Artwork']).cumsum(), label='Artist & Artwork')
l3, = ax[1].plot(np.array(cat2cnt['Artist & Artist']).cumsum(), label='Artist & Artist')

ax[1].plot(np.array(base_df['Artwork&Artwork']), linestyle='--', color=l1.get_color())
ax[1].plot(np.array(base_df['Artist&Artwork']), linestyle='--', color=l2.get_color())
ax[1].plot(np.array(base_df['Artist&Artist']), linestyle='--', color=l3.get_color())

ax[1].legend()

tmp_df = pds.DataFrame()
tmp_df['Artwork & Artwork'] = np.array(cat2cnt['Artwork & Artwork']).cumsum()
tmp_df['Artist & Artwork'] = np.array(cat2cnt['Artist & Artwork']).cumsum()
tmp_df['Artist & Artist'] = np.array(cat2cnt['Artist & Artist']).cumsum()

tmp_df['# of rank'] = [i for i in range(1, tmp_df.shape[0]+1)]
